# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
from scipy.optimize import curve_fit

M = 10000
N = 100 #number of blocks

x1 = np.arange(N)
x2 = np.arange(N)
x3 = np.arange(N)
x4 = np.arange(N)
y = np.loadtxt("output_epot_ave.dat", unpack='true')
z = np.loadtxt("output_etot_ave.dat", unpack='true')
w = np.loadtxt("output_ekin_ave.dat", unpack='true')
t = np.loadtxt("output_temp_ave.dat", unpack='true')
errory = np.loadtxt("output_epot_error.dat", unpack='true')
errorz = np.loadtxt("output_etot_error.dat", unpack='true')
errorw = np.loadtxt("output_ekin_error.dat", unpack='true')
errort = np.loadtxt("output_temp_error.dat", unpack='true')

plt.axes([0., 0., 2., 2.])
#plt.errorbar(x1, y, yerr=errory)
#plt.errorbar(x2, z, yerr=errorz)
#plt.errorbar(x3, w, yerr=errorw)
plt.errorbar(x4, t, yerr=errort)

plt.legend(["Energia potenziale", "Enegia totale", "Energia cinetica", "Temperatura"], loc ="best")

plt.xlabel('Blocchi')
plt.title('Plot energie')
plt.grid(True)


plt.show()

plt.show()
